# %%
#Each new term in the Fibonacci sequence is generated by adding the previous two terms. By starting with 
#By considering the terms in the Fibonacci sequence whose values do not exceed four million,
#find the sum of the even-valued terms.

#Generate Fibonacci
int1 = 0
int2 = 1
tmp_val = 0
max_sum = 4000000
sum_fibonacci = 0

for i in range (1,1000000):
    tmpval = int1+int2
    int1=int2
    int2=tmpval
    
    if (tmpval <= max_sum and tmpval%2==0):
        sum_fibonacci += tmpval
    if tmpval > max_sum:
        print("voldoende fibonacci gevonden")
        print (tmpval)
        break
print(sum_fibonacci)
# Out:
# voldoende fibonacci gevonden
# 5702887
# 4613732
